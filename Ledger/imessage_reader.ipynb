# %%
from imessage_reader import fetch_data
from os.path import expanduser
import sqlite3

# %%
fd = fetch_data.FetchData()
message = fd.get_messages()
print(message[0])
# Out:
# ('+821028506021', '나중에 전화드려도 될까요?', '2022-10-15 12:44:42', 'iMessage', '+821055375278', 0)

# %%
print(message)
# Out:
# [('+821028506021', '나중에 전화드려도 될까요?', '2022-10-15 12:44:42', 'iMessage', '+821055375278', 0), ('+821028506021', '카톡이 또 안된단 ', '2022-10-16 20:04:01', 'iMessage', '+821055375278', 0), ('+821028506021', '그래?', '2022-10-16 20:05:11', 'iMessage', '+821055375278', 1), ('+821028506021', '다른 메신저도 해볼까!?', '2022-10-16 20:05:21', 'iMessage', '+821055375278', 1), ('+821028506021', '라인깔아보까 캬캬', '2022-10-16 20:06:01', 'iMessage', '+821055375278', 0), ('+821028506021', '응!ㅋㅋ해볼래ㅋㅋ', '2022-10-16 20:06:24', 'iMessage', '+821055375278', 1), ('+821028506021', '나중에 전화드려도 될까요?', '2022-10-23 18:23:44', 'iMessage', '+821055375278', 1), ('+821028506021', '카톡이 또 안간당 ', '2022-11-02 23:36:58', 'iMessage', '+821055375278', 0), ('+821028506021', '잘자용', '2022-11-02 23:37:01', 'iMessage', '+821055375278', 0), ('+821028506021', '🥰', '2022-11-02 23:37:09', 'iMessage', '+821055375278', 0), ('+821028506021', '헐', '2022-11-02 23:37:14', 'iMessage', '+821055375278', 1), ('+821028506021', '그랭!!ㅎㅎ', '2022-11-02 23:37:17', 'iMessage', '+821055375278', 1), ('+821028506021', '잘자!❤️\u200d🔥', '2022-11-02 23:37:21', 'iMessage', '+821055375278', 1), ('+821028506021', '나중에 전화드려도 될까요?', '2022-12-09 23:48:45', 'iMessage', '+821055375278', 0), ('+821028506021', '카톡이 이상하넹 ', '2022-12-31 00:05:25', 'iMessage', '+821055375278', 0), ('+821028506021', '잘자욤', '2022-12-31 00:05:29', 'iMessage', '+821055375278', 0), ('+821028506021', '응응~~', '2022-12-31 00:06:05', 'iMessage', '+821055375278', 1), ('+821028506021', '굳밤', '2022-12-31 00:06:11', 'iMessage', '+821055375278', 1), ('+821028506021', '🥰', '2022-12-31 00:06:13', 'iMessage', '+821055375278', 1), ('+821028506021', '💙', '2022-12-31 00:06:22', 'iMessage', '+821055375278', 0), ('+821028506021', '나중에 전화드려도 될까요?', '2023-01-23 21:08:03', 'iMessage', '+821055375278', 0), ('+821029718790', '안녕하십니까,\nSF분석팀 박영준 선임입니다. 회의실 사용 말씀드렸고 저희 교육시간은 30분 미뤘습니다. 내선 전화를 안 받으셔서 문자 드립니다. ', '2022-05-26 09:08:15', 'iMessage', '+821055375278', 1), ('+821029718790', '감사합니다. 회의 들어와서 못받았네요. 10시까지만 사용할께요.', '2022-05-26 09:09:53', 'iMessage', '+821055375278', 0), ('+821040049370', '고객님 내일 1:00 정도나\n4:00 정도 정검 가능하신지\n문자좀 주세요~', '2021-12-09 20:08:22', 'iMessage', '+821055375278', 0), ('+821040049370', '네시 가능합니다', '2021-12-09 20:08:33', 'iMessage', '+821055375278', 1), ('+821040049370', '감사합니다~', '2021-12-09 20:09:22', 'iMessage', '+821055375278', 0), ('+821040049370', '안녕하세요 sk매직입니다\n고객님 공기청정기 정검\n금요일 2:00-2:30\n토요일 2:30 정도 가능하신가요? 스케줄 확인좀 부탁드립니다', '2022-04-07 12:10:23', 'iMessage', '+821055375278', 0), ('+821040049370', '연락이 늦어 죄송합니다ㅠ 제가 정신이 앖어서 다음주는 괜찮으실까요? ', '2022-04-08 16:02:56', 'iMessage', '+821055375278', 1), ('+821040049370', '네~^^\n다음주에 연락드리겠습니다~', '2022-04-08 16:19:36', 'iMessage', '+821055375278', 0), ('+821040049370', '안녕하세요 sk매직입니다\n공기청정기정검 토요일\n11:00 정도 가능하신가요?', '2022-04-14 14:23:05', 'iMessage', '+821055375278', 0), ('+821040049370', '잠시만요', '2022-04-14 14:23:38', 'iMessage', '+821055375278', 1), ('+821040049370', '네~', '2022-04-14 14:27:17', 'iMessage', '+821055375278', 0), ('+821040049370', '넵 토요일 11시 부탁드릴게요', '2022-04-14 16:37:20', 'iMessage', '+821055375278', 1), ('+821040049370', '감사합니다', '2022-04-14 16:59:32', 'iMessage', '+821055375278', 0), ('+821040049370', '안녕하세요 sk매직입니다\n내일은 정검날이십니다~\n내일뵙겠습니다~^^', '2022-04-15 18:04:45', 'iMessage', '+821055375278', 0), ('+821040105717', '안녕하세요. \n효성ITX 박영준 선임입니다. \n\n퇴근하셨을 것 같아 문자 드립니다. \n내일 방문시 차량 이용으로 인하여 차량방문 등록 요청드릴게요. \n\n차량 번호: 42부 3874\n방문 시간: 오전 10시\n\n이상입니다!', '2023-01-16 17:46:31', 'iMessage', '+821055375278', 1), ('+821040105717', '넵 등록해놓겠습니다!', '2023-01-16 17:51:50', 'iMessage', '+821055375278', 0), ('+821046049466', '가동실적에 대해서 9시 17분에 업데이트한 내용을 로드한 것으러 보입니다. \n\n생산일보는 45분에 재로드가 되는데, 그 이후 시간에도 내용이 제대로 반영이 안 되어 있다면 다시 연락주시기 바랍니다.', '2021-11-30 09:40:12', 'iMessage', '+821055375278', 1), ('+821046049466', '네 감사합니다', '2021-11-30 09:43:28', 'iMessage', '+821055375278', 0), ('+821046049466', '안녕하세요 일보 확인하엿고 이상없습니다 재 발송 부탁드립니다', '2021-12-29 11:18:28', 'iMessage', '+821055375278', 0), ('+821046049 ...

# %%
def fetch_db_data(db, command):
    try:
        conn = sqlite3.connect(db)
        cur = conn.cursor()
        cur.execute(command)
        return cur.fetchall()
    except Exception as e:
        sys.exit("Error reading the database: %s" %e)

# %%
db_path = expanduser("~") + "/Library/Messages/chat.db"
query = """SELECT text, handle.id, handle.service, message.destination_caller_id, message.is_from_me FROM message JOIN handle ON message.handle_id = handle.ROWID
WHERE handle.id == '+8215447200'"""

# %%
rval = fetch_db_data(db_path, query)
rval[0]
# Out:
# ('[Web발신]\n[신한체크승인] 박*준(2709) 01/27 15:06 4,000원 플라이팬 잔액33,302원',
#  '+8215447200',
#  'SMS',
#  '+821055375278',
#  0)

# %% [markdown]
# postgre db에 텍스트 저장 scheme을 만들어 테이블 생성한 후, sms 데이터 저장
# 테이블1 카드 아이디, 날짜, 시간, 금액, 사업장 순으로 저장
# 이거만 되도 개꿀임
# 연결 테이블1 - 카드 아이디 정보 등록 테이블
# 연결 테이블2 - 테이블1 의 record 별 처리 완료 boolean 생성
